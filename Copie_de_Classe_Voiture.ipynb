# %% [markdown]
# ### Création d'une classe voiture avec 2 attributs, 4 méthodes et 1 constructeur

# %%
class Voiture:
  # Attributs
  couleur = ""
  immatriculation = ""
  vitesse = 0
  # Méthodes
  def demarrer(self):
    self.demarree = True
    print("Moteur démarré")
    return
  def accelerer(self):
    if self.vitesse < 100;
       self.vitesse += 10
       print(self.vitesse)
    else:
        print("vitesse max atteinte")
    return
  def freiner(self):
    if self.vitesse > 0
      self.vitesse+=10
    else:
       print("vitese min atteinte = 0 km/h")
    return
  def arreter(self):
    if
    return
  # Constructeur
  def __init__(self):
    self.demarree = False
    print("Création d'un nouvel objet instance de la classe Voiture")
    self.vitesse = 0
# Out:
#   File "/tmp/ipython-input-1749926807.py", line 12
#     if self.vitesse < 100;
#                          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Instanciation

# %%
laTeslaDeMrX = Voiture()

# %% [markdown]
# ### Définition des propriétés

# %%
laTeslaDeMrX.couleur = "rouge"
laTeslaDeMrX.immatriculation = "AB-123-CD"
print(laTeslaDeMrX.couleur)
print(laTeslaDeMrX.demarree)

# %% [markdown]
# ### Appel d'une méthode

# %%
laTeslaDeMrX.demarrer()
laTeslaDeMrX.accélerer()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3117159541.py in <cell line: 0>()
# ----> 1 laTeslaDeMrX.demarrer()
#       2 laTeslaDeMrX.accélerer()
#
# NameError: name 'laTeslaDeMrX' is not defined

# %% [markdown]
# ### Exercice :
#
#
# *   Coder les méthodes **accelerer**() et **freiner**() pour une modification de la vitesse de **10 Km/h** à condition que l'attribut **demarree** soit égal à **True**.
# *   Ces méthodes doivent afficher la nouvelle vitesse, qui ne pourra pas excéder 100 Km/h ni être négative.
# *   Modifier le constructeur pour qu'on puisse passer en paramètres la **couleur** et l'**immatriculation**.
# *   Coder un programme qui :
#   - instancie une voiture **rouge** immatriculée **AB-123-CD** (constructeur),
#   - démarre (demarrer()),
#   - accélère 12 fois (accelerer() 12 fois),
#   - s'arrête (arreter()),
#   - freine 12 fois (freiner() 12 fois),
#   - s'arrête (arreter()).
